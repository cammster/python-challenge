# %%
import os
import csv
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
filename1='employee_data1.csv'
filename2='employee_data2.csv'
filepath1=os.path.join(filename1)
filepath2=os.path.join(filename2)
employeeid=[]
employeefullname=[]
dob=[]
ssn=[]
state=[]

# %%
with open (filepath1,'r',newline='') as csvfile:
    file1data=csv.reader(csvfile,delimiter=",")
    for row in file1data:
        employeeid.append(row[0])
        employeefullname.append(row[1])
        dob.append(row[2])
        ssn.append(row[3])
        state.append(row[4])
state
# Out:
# ['State',
#  'Florida',
#  'Colorado',
#  'Pennsylvania',
#  'Michigan',
#  'Minnesota',
#  'New York',
#  'Wisconsin',
#  'Tennessee',
#  'West Virginia',
#  'Missouri',
#  'Montana',
#  'Iowa',
#  'Illinois',
#  'Georgia',
#  'Rhode Island',
#  'Louisiana',
#  'North Dakota',
#  'Nebraska',
#  'Florida',
#  'Oklahoma',
#  'Alabama',
#  'Louisiana',
#  'Oregon',
#  'North Carolina',
#  'South Dakota',
#  'New Hampshire',
#  'Washington',
#  'Indiana',
#  'New Jersey',
#  'Mississippi',
#  'Mississippi',
#  'Oklahoma',
#  'Connecticut',
#  'Hawaii',
#  'Montana',
#  'Kentucky',
#  'New Mexico',
#  'Colorado',
#  'Idaho',
#  'South Dakota',
#  'New Hampshire',
#  'West Virginia',
#  'South Dakota',
#  'Maine',
#  'Nebraska',
#  'South Dakota',
#  'Mississippi',
#  'New Mexico',
#  'Virginia',
#  'Arizona',
#  'Georgia',
#  'Montana',
#  'Indiana',
#  'Arizona',
#  'Oklahoma',
#  'North Dakota',
#  'Nevada',
#  'California',
#  'North Carolina',
#  'New Mexico',
#  'Nevada',
#  'Minnesota',
#  'Delaware',
#  'Alaska',
#  'Georgia',
#  'South Carolina',
#  'Ohio',
#  'Kentucky',
#  'Alabama',
#  'Ohio',
#  'New Jersey',
#  'Idaho',
#  'Arizona',
#  'South Carolina',
#  'Mississippi',
#  'Utah',
#  'Delaware',
#  'Indiana',
#  'Alabama',
#  'Louisiana',
#  'Utah',
#  'Ohio',
#  'Wyoming',
#  'California',
#  'Tennessee',
#  'Wyoming',
#  'Vermont',
#  'Nevada',
#  'Indiana',
#  'West Virginia',
#  'Alaska',
#  'Colorado',
#  'California',
#  'Wisconsin',
#  'Oregon',
#  'Maryland',
#  'Pennsylvania',
#  'Nebraska',
#  'West Virginia',
#  'Delaware',
#  'Ohio',
#  'Wyoming',
#  'New Hampshire',
#  'North Dakota',
#  'Alaska',
#  'Vermont',
#  'Florida',
#  'Montana',
#  'Louisiana',
#  'Iowa',
#  'Michigan',
#  'Nebraska',
#  'Maryland',
#  'California',
#  'Alaska',
#  'Mississippi',
#  'North Dakota',
#  'New Hampshire',
#  'Florida',
#  'Maine',
#  'Hawaii',
#  'Kansas',
#  'New York',
#  'Connecticut',
#  'Wisconsin',
#  'Vermont',
#  'Indiana',
#  'Delaware',
#  'Georgia',
#  'Connecticut',
#  'Colorado',
#  'Washington',
#  'Connecticut',
#  'Texas',
#  'Tennessee',
#  'Louisiana',
#  'Montana',
#  'Texas',
#  'Maine',
#  'Vermont',
#  'Nebraska',
#  'Florida',
#  'Florida',
#  'Ohio',
#  'Wisconsin',
#  'Michigan',
#  'Oregon',
#  'Alaska',
#  'Illinois',
#  'Wisconsin',
#  'Rhode Island',
#  'Illinois',
#  'Arkansas',
#  'Utah',
#  'Georgia',
#  'California',
#  'Nebraska',
#  'Arkansas',
#  'Idaho',
#  'Michigan',
#  'Florida',
#  'Wisconsin',
#  'Texas',
#  'South Carolina',
#  'Rhode Island',
#  'Kentucky',
#  'Washington',
#  'Arkansas',
#  'New Mexico',
#  'Arizona',
#  'Alabama',
#  'Vermont',
#  'South Dakota',
#  'Minnesota',
#  'Utah',
#  'West Virginia',
#  'Massachusetts',
#  'Nebraska',
#  'New Mexico',
#  'Kentucky',
#  'New Jersey',
#  'Nebraska',
#  'Iowa',
#  'Colorado',
#  'Arizona',
#  'Rhode Island',
#  'North Carolina',
#  'New York',
#  'New York',
#  'Virginia',
#  'Florida',
#  'Nevada',
#  'Utah',
#  'New Jersey',
#  'Delaware',
#  'North Dakota',
#  'Georgia',
#  'Mississippi',
#  'Washington',
#  'Kansas',
#  'Iowa',
#  'Montana',
#  'Arizona',
#  'Idaho',
#  'Montana',
#  'New York',
#  'Arkansas',
#  'South Carolina',
#  'Maryland',
#  'Indiana',
#  'South Carolina',
#  'California',
#  'Maryland',
#  'Florida',
#  'California',
#  'Nevada',
#  'New Mexico',
#  'Colorado',
#  'Illinois',
#  'Connecticut',
#  'New York',
#  'Maryland',
#  'Mississippi',
#  'Kansas',
#  'Maryland',
#  'Nebraska',
#  'Maine',
#  'Florida',
#  'Wyoming',
#  'Illinois',
#  'West Virginia',
#  'Minnesota',
#  'Indiana',
#  'Nebraska',
#  'Ohio',
#  'Illinois',
#  'South Carolina',
#  'Tennessee',
#  'Iowa',
#  'South Dakota',
#  'Indiana',
#  'West Virginia',
#  'Idaho',
#  'Washington',
#  'Wyoming',
#  'Kentucky',
#  'New York',
#  'Alaska',
#  'West Virginia',
#  'Tennessee',
#  'Kansas',
#  'Rhode Island',
#  'Michigan',
#  'Nevada',
#  'Utah',
#  'Massachusetts',
#  'Nebraska',
#  'Michigan',
#  'Vermont',
#  'New Jersey',
#  'Mississippi',
#  'Montana',
#  'South Carolina',
#  'Georgia',
#  'New Hampshire',
#  'Kentucky',
#  'Pennsylvania',
#  'Vermont',
#  'New Hampshire',
#  'New Hampshire',
#  'Illinois',
#  'Rhode Island',
#  'Kansas',
#  'West Virginia',
#  'Kansas',
#  'North Carolina',
#  'Iowa',
#  'Arizona',
#  'Indiana',
#  'Wisconsin',
#  'North Dakota',
#  'Oregon',
#  'Wisconsin',
#  'Pennsylvania',
#  'Alabama',
#  'Minnesota',
#  'Pennsylvania',
#  'Kansas',
#  'New York',
#  'Illinois',
#  'California',
#  'Delaware',
#  'Oregon',
#  'Wyoming',
#  'Indiana',
#  'Pennsylvania',
#  'Illinois',
#  'Rhode Island',
#  'Georgia',
#  'Georgia',
#  'Minnesota',
#  'Kansas',
#  'Wyoming',
#  'North Carolina',
#  'Wisconsin',
#  'Colorado',
#  'Montana',
#  'Massachusetts',
#  'Massachusetts',
#  'North Carolina',
#  'South Carolina',
#  'California',
#  'Wyoming',
#  'Hawaii',
#  'New Mexico',
#  'South Carolina',
#  'Massachusetts',
#  'Pennsylvania',
#  'Georgia',
#  'New York',
#  'Nevada',
#  'Oregon',
#  'Arkansas',
#  'Arizona',
#  'Minnesota',
#  'Arkansas',
#  'Georgia',
#  'New Mexico',
#  'New Jersey',
#  'Missouri',
#  'Missouri',
#  'Kansas',
#  'Massachusetts',
#  'Mississippi',
#  'Connecticut',
#  'Maryland',
#  'South Carolina',
#  'Vermont',
#  'Arkansas',
#  'Washington',
#  'Alabama',
#  'New Jersey',
#  'Alaska',
#  'Arizona',
#  'Arizona',
#  'Iowa',
#  'Kentucky',
#  'North Carolina',
#  'Michigan',
#  'Oklahoma',
#  'Texas',
#  'Montana',
#  'Arkansas',
#  'North Carolina',
#  'Missouri',
#  'Florida',
#  'West Virginia',
#  'Missouri',
#  'Florida',
#  'Utah',
#  'Washington',
#  'North Dakota',
#  'Massachusetts',
#  'Maine',
#  'South Carolina',
#  'Massachusetts',
#  'Alaska',
#  'South Dakota',
#  'Illinois',
#  'Georgia',
#  'Washington',
#  'North Carolina',
#  'New Hampshire',
#  'Mississippi',
#  'Nevada',
#  'Mississippi',
#  'Montana',
#  'Washington',
#  'New Hampshire',
#  'Maine',
#  'Tennessee',
#  'Louisiana',
#  'Indiana',
#  'Washington',
#  'Texas',
#  'Colorado',
#  'South Carolina',
#  'Montana',
#  'Arkansas',
#  'Utah',
#  'Arizona',
#  'Virginia',
#  'Virginia',
#  'Mississippi',
#  'Mississippi',
#  'Mississippi',
#  'New Mexico',
#  'Delaware',
#  'South Dakota',
#  'Tennessee',
#  'Connecticut',
#  'Vermont',
#  'Connecticut',
#  'Rhode Island',
#  'Idaho',
#  'New York',
#  'Tennessee',
#  'Colorado',
#  'Pennsylvania',
#  'Alaska',
#  'Colorado',
#  'Louisiana',
#  'Wyoming',
#  'Arizona',
#  'Massachusetts',
#  'Hawaii',
#  'Colorado',
#  'Louisiana',
#  'Maine',
#  'Idaho',
#  'Oklahoma',
#  'Wisconsin',
#  'Massachusetts',
#  'Washington',
#  'California',
#  'California',
#  'Alabama',
#  'Delaware',
#  'Rhode Island',
#  'Kentucky',
#  'New Jersey',
#  'Massachusetts',
#  'North Carolina',
#  'Ohio',
#  'Indiana',
#  'Florida',
#  'Utah',
#  'Tennessee',
#  'Arizona',
#  'North Carolina',
#  'Colorado',
#  'Washington',
#  'Idaho',
#  'New Mexico',
#  'Michigan',
#  'Florida',
#  'Alabama',
#  'South Dakota',
#  'Georgia',
#  'North Dakota',
#  'Alabama',
#  'Vermont',
#  'Texas',
#  'New York',
#  'Massachusetts',
#  'New Mexico',
#  'Louisiana',
#  'Indiana',
#  'Ohio',
#  'Mississippi',
#  'South Carolina',
#  'Virginia',
#  'Georgia',
#  'Connecticut',
#  'North Dakota',
#  'Indiana',
#  'Arkansas',
#  'New Mexico',
#  'California',
#  'Texas',
#  'Indiana',
#  'Hawaii',
#  'Rhode Island',
#  'New Jersey',
#  'Mississippi',
#  'Tennessee',
#  'Tennessee',
#  'New York',
#  'North Carolina',
#  'South Carolina',
#  'Florida',
#  'New Jersey',
#  'Illinois',
#  'Delaware',
#  'Hawaii',
#  'Virginia',
#  'California',
#  'New Hampshire',
#  'Iowa',
#  'North Dakota',
#  'Maine',
#  'Colorado',
#  'Oklahoma',
#  'Kentucky',
#  'Vermont',
#  'Alabama',
#  'Hawaii',
#  'Tennessee',
#  'Mississippi',
#  'Nevada',
#  'Idaho',
#  'Hawaii',
#  'Connecticut',
#  'Hawaii',
#  'Florida',
#  'Oklahoma',
#  'South Carolina',
#  'Vermont',
#  'Arizona',
#  'Michigan',
#  'New Jersey',
#  'Oregon',
#  'Connecticut',
#  'Illinois',
#  'Nebraska',
#  'Wisconsin',
#  'Nebraska',
#  'Indiana',
#  'Pennsylvania',
#  'New Mexico',
#  'Florida',
#  'Indiana',
#  'Indiana',
#  'Virginia',
#  'Massachusetts',
#  'Vermont',
#  'Massachusetts',
#  'Missouri',
#  'California',
#  'Ohio',
#  'Nevada',
#  'North Dakota',
#  'Colorado',
#  'Connecticut',
#  'Oregon',
#  'New York',
#  'South Dakota',
#  'South Dakota',
#  'Pennsylvania',
#  'Pennsylvania',
#  'Pennsylvania',
#  'California',
#  'Delaware',
#  'Utah',
#  'South Carolina',
#  'Ohio',
#  'Kansas',
#  'West Virginia',
#  'Ohio',
#  'Oklahoma',
#  'Kansas',
#  'North Dakota',
#  'Georgia',
#  'Arizona',
#  'Maryland',
#  'Arizona',
#  'New Jersey',
#  'Alaska',
#  'Oklahoma',
#  'Nevada',
#  'Iowa',
#  'Alabama',
#  'Rhode Island',
#  'Arkansas',
#  'North Carolina',
#  'Missouri',
#  'Louisiana',
#  'South Dakota',
#  'North Dakota',
#  'South Carolina',
#  'Arkansas',
#  'Maryland',
#  'Rhode Island',
#  'Nevada',
#  'Iowa',
#  'Idaho',
#  'South Dakota',
#  'California',
#  'Massachusetts',
#  'Ohio',
#  'Minnesota',
#  'South Dakota',
#  'New Mexico',
#  'Illinois',
#  'Michigan',
#  'Missouri',
#  'Nebraska',
#  'Kentucky',
#  'North Carolina',
#  'Hawaii',
#  'Alabama',
#  'Florida',
#  'Washington',
#  'North Dakota',
#  'Virginia',
#  'Maine',
#  'Indiana',
#  'Pennsylvania',
#  'Louisiana',
#  'Delaware',
#  'Oregon',
#  'Minnesota',
#  'North Dakota',
#  'Wisconsin',
#  'Maryland',
#  'Georgia',
#  'Kentucky',
#  'Oklahoma',
#  'Oregon',
#  'Nebraska',
#  'Oregon',
#  'South Dakota',
#  'Nevada',
#  'Alabama',
#  'Nebraska',
#  'Connecticut',
#  'Minnesota',
#  'Wyoming',
#  'Massachusetts',
#  'Oregon',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'Missouri',
#  'Florida',
#  'New Mexico',
#  'Louisiana',
#  'Kansas',
#  'Colorado',
#  'Kentucky',
#  'Georgia',
#  'Iowa',
#  'New York',
#  'Minnesota',
#  'Kentucky',
#  'Oregon',
#  'Maryland',
#  'West Virginia',
#  'Kansas',
#  'Minnesota',
#  'South Carolina',
#  'Alabama',
#  'California',
#  'New York',
#  'Maine',
#  'Colorado',
#  'Louisiana',
#  'Delaware',
#  'Arkansas',
#  'Iowa']

# %%
file1length=len(employeeid)
with open (filepath2,'r',newline='') as csvfile:
    file2data=csv.reader(csvfile,delimiter=",")
    for row in file2data:
        employeeid.append(row[0])
        employeefullname.append(row[1])
        dob.append(row[2])
        ssn.append(row[3])
        state.append(row[4])
state
# Out:
# ['State',
#  'Florida',
#  'Colorado',
#  'Pennsylvania',
#  'Michigan',
#  'Minnesota',
#  'New York',
#  'Wisconsin',
#  'Tennessee',
#  'West Virginia',
#  'Missouri',
#  'Montana',
#  'Iowa',
#  'Illinois',
#  'Georgia',
#  'Rhode Island',
#  'Louisiana',
#  'North Dakota',
#  'Nebraska',
#  'Florida',
#  'Oklahoma',
#  'Alabama',
#  'Louisiana',
#  'Oregon',
#  'North Carolina',
#  'South Dakota',
#  'New Hampshire',
#  'Washington',
#  'Indiana',
#  'New Jersey',
#  'Mississippi',
#  'Mississippi',
#  'Oklahoma',
#  'Connecticut',
#  'Hawaii',
#  'Montana',
#  'Kentucky',
#  'New Mexico',
#  'Colorado',
#  'Idaho',
#  'South Dakota',
#  'New Hampshire',
#  'West Virginia',
#  'South Dakota',
#  'Maine',
#  'Nebraska',
#  'South Dakota',
#  'Mississippi',
#  'New Mexico',
#  'Virginia',
#  'Arizona',
#  'Georgia',
#  'Montana',
#  'Indiana',
#  'Arizona',
#  'Oklahoma',
#  'North Dakota',
#  'Nevada',
#  'California',
#  'North Carolina',
#  'New Mexico',
#  'Nevada',
#  'Minnesota',
#  'Delaware',
#  'Alaska',
#  'Georgia',
#  'South Carolina',
#  'Ohio',
#  'Kentucky',
#  'Alabama',
#  'Ohio',
#  'New Jersey',
#  'Idaho',
#  'Arizona',
#  'South Carolina',
#  'Mississippi',
#  'Utah',
#  'Delaware',
#  'Indiana',
#  'Alabama',
#  'Louisiana',
#  'Utah',
#  'Ohio',
#  'Wyoming',
#  'California',
#  'Tennessee',
#  'Wyoming',
#  'Vermont',
#  'Nevada',
#  'Indiana',
#  'West Virginia',
#  'Alaska',
#  'Colorado',
#  'California',
#  'Wisconsin',
#  'Oregon',
#  'Maryland',
#  'Pennsylvania',
#  'Nebraska',
#  'West Virginia',
#  'Delaware',
#  'Ohio',
#  'Wyoming',
#  'New Hampshire',
#  'North Dakota',
#  'Alaska',
#  'Vermont',
#  'Florida',
#  'Montana',
#  'Louisiana',
#  'Iowa',
#  'Michigan',
#  'Nebraska',
#  'Maryland',
#  'California',
#  'Alaska',
#  'Mississippi',
#  'North Dakota',
#  'New Hampshire',
#  'Florida',
#  'Maine',
#  'Hawaii',
#  'Kansas',
#  'New York',
#  'Connecticut',
#  'Wisconsin',
#  'Vermont',
#  'Indiana',
#  'Delaware',
#  'Georgia',
#  'Connecticut',
#  'Colorado',
#  'Washington',
#  'Connecticut',
#  'Texas',
#  'Tennessee',
#  'Louisiana',
#  'Montana',
#  'Texas',
#  'Maine',
#  'Vermont',
#  'Nebraska',
#  'Florida',
#  'Florida',
#  'Ohio',
#  'Wisconsin',
#  'Michigan',
#  'Oregon',
#  'Alaska',
#  'Illinois',
#  'Wisconsin',
#  'Rhode Island',
#  'Illinois',
#  'Arkansas',
#  'Utah',
#  'Georgia',
#  'California',
#  'Nebraska',
#  'Arkansas',
#  'Idaho',
#  'Michigan',
#  'Florida',
#  'Wisconsin',
#  'Texas',
#  'South Carolina',
#  'Rhode Island',
#  'Kentucky',
#  'Washington',
#  'Arkansas',
#  'New Mexico',
#  'Arizona',
#  'Alabama',
#  'Vermont',
#  'South Dakota',
#  'Minnesota',
#  'Utah',
#  'West Virginia',
#  'Massachusetts',
#  'Nebraska',
#  'New Mexico',
#  'Kentucky',
#  'New Jersey',
#  'Nebraska',
#  'Iowa',
#  'Colorado',
#  'Arizona',
#  'Rhode Island',
#  'North Carolina',
#  'New York',
#  'New York',
#  'Virginia',
#  'Florida',
#  'Nevada',
#  'Utah',
#  'New Jersey',
#  'Delaware',
#  'North Dakota',
#  'Georgia',
#  'Mississippi',
#  'Washington',
#  'Kansas',
#  'Iowa',
#  'Montana',
#  'Arizona',
#  'Idaho',
#  'Montana',
#  'New York',
#  'Arkansas',
#  'South Carolina',
#  'Maryland',
#  'Indiana',
#  'South Carolina',
#  'California',
#  'Maryland',
#  'Florida',
#  'California',
#  'Nevada',
#  'New Mexico',
#  'Colorado',
#  'Illinois',
#  'Connecticut',
#  'New York',
#  'Maryland',
#  'Mississippi',
#  'Kansas',
#  'Maryland',
#  'Nebraska',
#  'Maine',
#  'Florida',
#  'Wyoming',
#  'Illinois',
#  'West Virginia',
#  'Minnesota',
#  'Indiana',
#  'Nebraska',
#  'Ohio',
#  'Illinois',
#  'South Carolina',
#  'Tennessee',
#  'Iowa',
#  'South Dakota',
#  'Indiana',
#  'West Virginia',
#  'Idaho',
#  'Washington',
#  'Wyoming',
#  'Kentucky',
#  'New York',
#  'Alaska',
#  'West Virginia',
#  'Tennessee',
#  'Kansas',
#  'Rhode Island',
#  'Michigan',
#  'Nevada',
#  'Utah',
#  'Massachusetts',
#  'Nebraska',
#  'Michigan',
#  'Vermont',
#  'New Jersey',
#  'Mississippi',
#  'Montana',
#  'South Carolina',
#  'Georgia',
#  'New Hampshire',
#  'Kentucky',
#  'Pennsylvania',
#  'Vermont',
#  'New Hampshire',
#  'New Hampshire',
#  'Illinois',
#  'Rhode Island',
#  'Kansas',
#  'West Virginia',
#  'Kansas',
#  'North Carolina',
#  'Iowa',
#  'Arizona',
#  'Indiana',
#  'Wisconsin',
#  'North Dakota',
#  'Oregon',
#  'Wisconsin',
#  'Pennsylvania',
#  'Alabama',
#  'Minnesota',
#  'Pennsylvania',
#  'Kansas',
#  'New York',
#  'Illinois',
#  'California',
#  'Delaware',
#  'Oregon',
#  'Wyoming',
#  'Indiana',
#  'Pennsylvania',
#  'Illinois',
#  'Rhode Island',
#  'Georgia',
#  'Georgia',
#  'Minnesota',
#  'Kansas',
#  'Wyoming',
#  'North Carolina',
#  'Wisconsin',
#  'Colorado',
#  'Montana',
#  'Massachusetts',
#  'Massachusetts',
#  'North Carolina',
#  'South Carolina',
#  'California',
#  'Wyoming',
#  'Hawaii',
#  'New Mexico',
#  'South Carolina',
#  'Massachusetts',
#  'Pennsylvania',
#  'Georgia',
#  'New York',
#  'Nevada',
#  'Oregon',
#  'Arkansas',
#  'Arizona',
#  'Minnesota',
#  'Arkansas',
#  'Georgia',
#  'New Mexico',
#  'New Jersey',
#  'Missouri',
#  'Missouri',
#  'Kansas',
#  'Massachusetts',
#  'Mississippi',
#  'Connecticut',
#  'Maryland',
#  'South Carolina',
#  'Vermont',
#  'Arkansas',
#  'Washington',
#  'Alabama',
#  'New Jersey',
#  'Alaska',
#  'Arizona',
#  'Arizona',
#  'Iowa',
#  'Kentucky',
#  'North Carolina',
#  'Michigan',
#  'Oklahoma',
#  'Texas',
#  'Montana',
#  'Arkansas',
#  'North Carolina',
#  'Missouri',
#  'Florida',
#  'West Virginia',
#  'Missouri',
#  'Florida',
#  'Utah',
#  'Washington',
#  'North Dakota',
#  'Massachusetts',
#  'Maine',
#  'South Carolina',
#  'Massachusetts',
#  'Alaska',
#  'South Dakota',
#  'Illinois',
#  'Georgia',
#  'Washington',
#  'North Carolina',
#  'New Hampshire',
#  'Mississippi',
#  'Nevada',
#  'Mississippi',
#  'Montana',
#  'Washington',
#  'New Hampshire',
#  'Maine',
#  'Tennessee',
#  'Louisiana',
#  'Indiana',
#  'Washington',
#  'Texas',
#  'Colorado',
#  'South Carolina',
#  'Montana',
#  'Arkansas',
#  'Utah',
#  'Arizona',
#  'Virginia',
#  'Virginia',
#  'Mississippi',
#  'Mississippi',
#  'Mississippi',
#  'New Mexico',
#  'Delaware',
#  'South Dakota',
#  'Tennessee',
#  'Connecticut',
#  'Vermont',
#  'Connecticut',
#  'Rhode Island',
#  'Idaho',
#  'New York',
#  'Tennessee',
#  'Colorado',
#  'Pennsylvania',
#  'Alaska',
#  'Colorado',
#  'Louisiana',
#  'Wyoming',
#  'Arizona',
#  'Massachusetts',
#  'Hawaii',
#  'Colorado',
#  'Louisiana',
#  'Maine',
#  'Idaho',
#  'Oklahoma',
#  'Wisconsin',
#  'Massachusetts',
#  'Washington',
#  'California',
#  'California',
#  'Alabama',
#  'Delaware',
#  'Rhode Island',
#  'Kentucky',
#  'New Jersey',
#  'Massachusetts',
#  'North Carolina',
#  'Ohio',
#  'Indiana',
#  'Florida',
#  'Utah',
#  'Tennessee',
#  'Arizona',
#  'North Carolina',
#  'Colorado',
#  'Washington',
#  'Idaho',
#  'New Mexico',
#  'Michigan',
#  'Florida',
#  'Alabama',
#  'South Dakota',
#  'Georgia',
#  'North Dakota',
#  'Alabama',
#  'Vermont',
#  'Texas',
#  'New York',
#  'Massachusetts',
#  'New Mexico',
#  'Louisiana',
#  'Indiana',
#  'Ohio',
#  'Mississippi',
#  'South Carolina',
#  'Virginia',
#  'Georgia',
#  'Connecticut',
#  'North Dakota',
#  'Indiana',
#  'Arkansas',
#  'New Mexico',
#  'California',
#  'Texas',
#  'Indiana',
#  'Hawaii',
#  'Rhode Island',
#  'New Jersey',
#  'Mississippi',
#  'Tennessee',
#  'Tennessee',
#  'New York',
#  'North Carolina',
#  'South Carolina',
#  'Florida',
#  'New Jersey',
#  'Illinois',
#  'Delaware',
#  'Hawaii',
#  'Virginia',
#  'California',
#  'New Hampshire',
#  'Iowa',
#  'North Dakota',
#  'Maine',
#  'Colorado',
#  'Oklahoma',
#  'Kentucky',
#  'Vermont',
#  'Alabama',
#  'Hawaii',
#  'Tennessee',
#  'Mississippi',
#  'Nevada',
#  'Idaho',
#  'Hawaii',
#  'Connecticut',
#  'Hawaii',
#  'Florida',
#  'Oklahoma',
#  'South Carolina',
#  'Vermont',
#  'Arizona',
#  'Michigan',
#  'New Jersey',
#  'Oregon',
#  'Connecticut',
#  'Illinois',
#  'Nebraska',
#  'Wisconsin',
#  'Nebraska',
#  'Indiana',
#  'Pennsylvania',
#  'New Mexico',
#  'Florida',
#  'Indiana',
#  'Indiana',
#  'Virginia',
#  'Massachusetts',
#  'Vermont',
#  'Massachusetts',
#  'Missouri',
#  'California',
#  'Ohio',
#  'Nevada',
#  'North Dakota',
#  'Colorado',
#  'Connecticut',
#  'Oregon',
#  'New York',
#  'South Dakota',
#  'South Dakota',
#  'Pennsylvania',
#  'Pennsylvania',
#  'Pennsylvania',
#  'California',
#  'Delaware',
#  'Utah',
#  'South Carolina',
#  'Ohio',
#  'Kansas',
#  'West Virginia',
#  'Ohio',
#  'Oklahoma',
#  'Kansas',
#  'North Dakota',
#  'Georgia',
#  'Arizona',
#  'Maryland',
#  'Arizona',
#  'New Jersey',
#  'Alaska',
#  'Oklahoma',
#  'Nevada',
#  'Iowa',
#  'Alabama',
#  'Rhode Island',
#  'Arkansas',
#  'North Carolina',
#  'Missouri',
#  'Louisiana',
#  'South Dakota',
#  'North Dakota',
#  'South Carolina',
#  'Arkansas',
#  'Maryland',
#  'Rhode Island',
#  'Nevada',
#  'Iowa',
#  'Idaho',
#  'South Dakota',
#  'California',
#  'Massachusetts',
#  'Ohio',
#  'Minnesota',
#  'South Dakota',
#  'New Mexico',
#  'Illinois',
#  'Michigan',
#  'Missouri',
#  'Nebraska',
#  'Kentucky',
#  'North Carolina',
#  'Hawaii',
#  'Alabama',
#  'Florida',
#  'Washington',
#  'North Dakota',
#  'Virginia',
#  'Maine',
#  'Indiana',
#  'Pennsylvania',
#  'Louisiana',
#  'Delaware',
#  'Oregon',
#  'Minnesota',
#  'North Dakota',
#  'Wisconsin',
#  'Maryland',
#  'Georgia',
#  'Kentucky',
#  'Oklahoma',
#  'Oregon',
#  'Nebraska',
#  'Oregon',
#  'South Dakota',
#  'Nevada',
#  'Alabama',
#  'Nebraska',
#  'Connecticut',
#  'Minnesota',
#  'Wyoming',
#  'Massachusetts',
#  'Oregon',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'Missouri',
#  'Florida',
#  'New Mexico',
#  'Louisiana',
#  'Kansas',
#  'Colorado',
#  'Kentucky',
#  'Georgia',
#  'Iowa',
#  'New York',
#  'Minnesota',
#  'Kentucky',
#  'Oregon',
#  'Maryland',
#  'West Virginia',
#  'Kansas',
#  'Minnesota',
#  'South Carolina',
#  'Alabama',
#  'California',
#  'New York',
#  'Maine',
#  'Colorado',
#  'Louisiana',
#  'Delaware',
#  'Arkansas',
#  'Iowa',
#  'State',
#  'Rhode Island',
#  'Wyoming',
#  'Nebraska',
#  'Louisiana',
#  'Wisconsin',
#  'Michigan',
#  'Vermont',
#  'Oregon',
#  'Kentucky',
#  'Washington',
#  'Pennsylvania',
#  'North Dakota',
#  'Minnesota',
#  'Texas',
#  'Maine',
#  'New Mexico',
#  'Oklahoma',
#  'California',
#  'Nevada',
#  'Arizona',
#  'Alaska',
#  'Tennessee',
#  'South Dakota',
#  'Maine',
#  'Oregon',
#  'Texas',
#  'South Carolina',
#  'Montana',
#  'South Dakota',
#  'Indiana',
#  'Washington',
#  'Oregon',
#  'South Carolina',
#  'Connecticut',
#  'South Dakota',
#  'Vermont',
#  'Louisiana',
#  'Minnesota',
#  'Kansas',
#  'Florida',
#  'North Dakota',
#  'Tennessee',
#  'New York',
#  'Missouri',
#  'Delaware',
#  'Maine',
#  'New Hampshire',
#  'California',
#  'Maine',
#  'Delaware',
#  'Arkansas',
#  'Idaho',
#  'Colorado',
#  'Alaska',
#  'Georgia',
#  'Tennessee',
#  'Idaho',
#  'New Hampshire',
#  'Oregon',
#  'Alaska',
#  'Georgia',
#  'Virginia',
#  'Georgia',
#  'West Virginia',
#  'Mississippi',
#  'Tennessee',
#  'Maryland',
#  'Nebraska',
#  'California',
#  'Iowa',
#  'Wyoming',
#  'Maine',
#  'Montana',
#  'New Hampshire',
#  'New York',
#  'Idaho',
#  'Idaho',
#  'Ohio',
#  'South Carolina',
#  'Mississippi',
#  'North Carolina',
#  'New Jersey',
#  'Nevada',
#  'New Mexico',
#  'West Virginia',
#  'Kansas',
#  'Maine',
#  'Iowa',
#  'Hawaii',
#  'North Dakota',
#  'Maryland',
#  'Ohio',
#  'Tennessee',
#  'Louisiana',
#  'Illinois',
#  'Arizona',
#  'New Hampshire',
#  'Wisconsin',
#  'Mississippi',
#  'Idaho',
#  'New York',
#  'New Jersey',
#  'West Virginia',
#  'Oregon',
#  'Michigan',
#  'Nevada',
#  'Wisconsin',
#  'Delaware',
#  'Massachusetts',
#  'Iowa',
#  'Rhode Island',
#  'Wyoming',
#  'Texas',
#  'North Dakota',
#  'Mississippi',
#  'Kansas',
#  'New Hampshire',
#  'Kansas',
#  'Alabama',
#  'Kentucky',
#  'New Jersey',
#  'Rhode Island',
#  'New Jersey',
#  'South Dakota',
#  'Rhode Island',
#  'Montana',
#  'Wisconsin',
#  'North Carolina',
#  'Maine',
#  'South Dakota',
#  'West Virginia',
#  'Florida',
#  'Idaho',
#  'North Carolina',
#  'New Jersey',
#  'Kansas',
#  'South Dakota',
#  'West Virginia',
#  'Wisconsin',
#  'Texas',
#  'Hawaii',
#  'Arizona',
#  'Louisiana',
#  'Hawaii',
#  'New York',
#  'Montana',
#  'Virginia',
#  'Texas',
#  'West Virginia',
#  'Minnesota',
#  'New York',
#  'Missouri',
#  'Arkansas',
#  'Kansas',
#  'Delaware',
#  'Colorado',
#  'Mississippi',
#  'Nevada',
#  'West Virginia',
#  'Missouri',
#  'Indiana',
#  'Tennessee',
#  'Illinois',
#  'Ohio',
#  'Virginia',
#  'Maine',
#  'Nevada',
#  'Maine',
#  'New York',
#  'Rhode Island',
#  'Montana',
#  'New Jersey',
#  'New Jersey',
#  'Oregon',
#  'Idaho',
#  'Hawaii',
#  'Oregon',
#  'Minnesota',
#  'Iowa',
#  'Georgia',
#  'Minnesota',
#  'Michigan',
#  'Georgia',
#  'South Carolina',
#  'Missouri',
#  'Colorado',
#  'South Dakota',
#  'South Carolina',
#  'Arkansas',
#  'North Carolina',
#  'Ohio',
#  'Louisiana',
#  'Vermont',
#  'North Carolina',
#  'Connecticut',
#  'Texas',
#  'North Carolina',
#  'Idaho',
#  'Arizona',
#  'Georgia',
#  'Iowa',
#  'New Jersey',
#  'North Carolina',
#  'Indiana',
#  'Kansas',
#  'Colorado',
#  'Tennessee',
#  'Tennessee',
#  'Maryland',
#  'Delaware',
#  'Texas',
#  'Alaska',
#  'Montana',
#  'Michigan',
#  'West Virginia',
#  'Connecticut',
#  'Michigan',
#  'Nevada',
#  'Nevada',
#  'Oklahoma',
#  'North Dakota',
#  'Wyoming',
#  'Oklahoma',
#  'New Jersey',
#  'Iowa',
#  'Rhode Island',
#  'Virginia',
#  'Connecticut',
#  'Michigan',
#  'Kentucky',
#  'Massachusetts',
#  'Idaho',
#  'South Carolina',
#  'Arizona',
#  'Kentucky',
#  'Oklahoma',
#  'Wyoming',
#  'Illinois',
#  'North Carolina',
#  'West Virginia',
#  'Louisiana',
#  'Indiana',
#  'Georgia',
#  'Wisconsin',
#  'Missouri',
#  'Virginia',
#  'Alabama',
#  'Iowa',
#  'Maine',
#  'Georgia',
#  'Alaska',
#  'Alabama',
#  'North Carolina',
#  'Nebraska',
#  'South Dakota',
#  'Michigan',
#  'Iowa',
#  'West Virginia',
#  'West Virginia',
#  'Illinois',
#  'Maine',
#  'Louisiana',
#  'Maine',
#  'Mississippi',
#  'Wisconsin',
#  'Idaho',
#  'Wisconsin',
#  'Texas',
#  'Louisiana',
#  'Alaska',
#  'Vermont',
#  'Ohio',
#  'New Hampshire',
#  'New Jersey',
#  'Oregon',
#  'Arizona',
#  'Oregon',
#  'Louisiana',
#  'Maine',
#  'Michigan',
#  'West Virginia',
#  'Arizona',
#  'Oregon',
#  'Virginia',
#  'Hawaii',
#  'California',
#  'Alabama',
#  'North Dakota',
#  'Kansas',
#  'Alabama',
#  'Minnesota',
#  'Kentucky',
#  'Pennsylvania',
#  'Wyoming',
#  'South Dakota',
#  'Oregon',
#  'Massachusetts',
#  'Michigan',
#  'Missouri',
#  'Michigan',
#  'Indiana',
#  'Nebraska',
#  'Wyoming',
#  'Vermont',
#  'Vermont',
#  'Nevada',
#  'New Mexico',
#  'Iowa',
#  'Indiana',
#  'West Virginia',
#  'West Virginia',
#  'Minnesota',
#  'Oregon',
#  'Delaware',
#  'Connecticut',
#  'Illinois',
#  'New Hampshire',
#  'Pennsylvania',
#  'Nebraska',
#  'Delaware',
#  'Illinois',
#  'New Jersey',
#  'North Carolina',
#  'Oklahoma',
#  'Oklahoma',
#  'North Dakota',
#  'New Hampshire',
#  'New Jersey',
#  'Tennessee',
#  'Alaska',
#  'Arizona',
#  'Indiana',
#  'Arkansas',
#  'New Jersey',
#  'New Hampshire',
#  'Indiana',
#  'Oregon',
#  'Missouri',
#  'Rhode Island',
#  'Iowa',
#  'Wyoming',
#  'Wisconsin',
#  'New York',
#  'Idaho',
#  'Utah',
#  'Alaska',
#  'Illinois',
#  'West Virginia',
#  ...]

# %%
del employeeid[file1length+1]
del employeefullname[file1length+1]
del dob[file1length+1]
del ssn[file1length+1]
del state[file1length+1]
numrows=len(employeeid)
numemployees=len(employeeid)-1 #Account for First Header Row
state
# Out:
# ['State',
#  'Florida',
#  'Colorado',
#  'Pennsylvania',
#  'Michigan',
#  'Minnesota',
#  'New York',
#  'Wisconsin',
#  'Tennessee',
#  'West Virginia',
#  'Missouri',
#  'Montana',
#  'Iowa',
#  'Illinois',
#  'Georgia',
#  'Rhode Island',
#  'Louisiana',
#  'North Dakota',
#  'Nebraska',
#  'Florida',
#  'Oklahoma',
#  'Alabama',
#  'Louisiana',
#  'Oregon',
#  'North Carolina',
#  'South Dakota',
#  'New Hampshire',
#  'Washington',
#  'Indiana',
#  'New Jersey',
#  'Mississippi',
#  'Mississippi',
#  'Oklahoma',
#  'Connecticut',
#  'Hawaii',
#  'Montana',
#  'Kentucky',
#  'New Mexico',
#  'Colorado',
#  'Idaho',
#  'South Dakota',
#  'New Hampshire',
#  'West Virginia',
#  'South Dakota',
#  'Maine',
#  'Nebraska',
#  'South Dakota',
#  'Mississippi',
#  'New Mexico',
#  'Virginia',
#  'Arizona',
#  'Georgia',
#  'Montana',
#  'Indiana',
#  'Arizona',
#  'Oklahoma',
#  'North Dakota',
#  'Nevada',
#  'California',
#  'North Carolina',
#  'New Mexico',
#  'Nevada',
#  'Minnesota',
#  'Delaware',
#  'Alaska',
#  'Georgia',
#  'South Carolina',
#  'Ohio',
#  'Kentucky',
#  'Alabama',
#  'Ohio',
#  'New Jersey',
#  'Idaho',
#  'Arizona',
#  'South Carolina',
#  'Mississippi',
#  'Utah',
#  'Delaware',
#  'Indiana',
#  'Alabama',
#  'Louisiana',
#  'Utah',
#  'Ohio',
#  'Wyoming',
#  'California',
#  'Tennessee',
#  'Wyoming',
#  'Vermont',
#  'Nevada',
#  'Indiana',
#  'West Virginia',
#  'Alaska',
#  'Colorado',
#  'California',
#  'Wisconsin',
#  'Oregon',
#  'Maryland',
#  'Pennsylvania',
#  'Nebraska',
#  'West Virginia',
#  'Delaware',
#  'Ohio',
#  'Wyoming',
#  'New Hampshire',
#  'North Dakota',
#  'Alaska',
#  'Vermont',
#  'Florida',
#  'Montana',
#  'Louisiana',
#  'Iowa',
#  'Michigan',
#  'Nebraska',
#  'Maryland',
#  'California',
#  'Alaska',
#  'Mississippi',
#  'North Dakota',
#  'New Hampshire',
#  'Florida',
#  'Maine',
#  'Hawaii',
#  'Kansas',
#  'New York',
#  'Connecticut',
#  'Wisconsin',
#  'Vermont',
#  'Indiana',
#  'Delaware',
#  'Georgia',
#  'Connecticut',
#  'Colorado',
#  'Washington',
#  'Connecticut',
#  'Texas',
#  'Tennessee',
#  'Louisiana',
#  'Montana',
#  'Texas',
#  'Maine',
#  'Vermont',
#  'Nebraska',
#  'Florida',
#  'Florida',
#  'Ohio',
#  'Wisconsin',
#  'Michigan',
#  'Oregon',
#  'Alaska',
#  'Illinois',
#  'Wisconsin',
#  'Rhode Island',
#  'Illinois',
#  'Arkansas',
#  'Utah',
#  'Georgia',
#  'California',
#  'Nebraska',
#  'Arkansas',
#  'Idaho',
#  'Michigan',
#  'Florida',
#  'Wisconsin',
#  'Texas',
#  'South Carolina',
#  'Rhode Island',
#  'Kentucky',
#  'Washington',
#  'Arkansas',
#  'New Mexico',
#  'Arizona',
#  'Alabama',
#  'Vermont',
#  'South Dakota',
#  'Minnesota',
#  'Utah',
#  'West Virginia',
#  'Massachusetts',
#  'Nebraska',
#  'New Mexico',
#  'Kentucky',
#  'New Jersey',
#  'Nebraska',
#  'Iowa',
#  'Colorado',
#  'Arizona',
#  'Rhode Island',
#  'North Carolina',
#  'New York',
#  'New York',
#  'Virginia',
#  'Florida',
#  'Nevada',
#  'Utah',
#  'New Jersey',
#  'Delaware',
#  'North Dakota',
#  'Georgia',
#  'Mississippi',
#  'Washington',
#  'Kansas',
#  'Iowa',
#  'Montana',
#  'Arizona',
#  'Idaho',
#  'Montana',
#  'New York',
#  'Arkansas',
#  'South Carolina',
#  'Maryland',
#  'Indiana',
#  'South Carolina',
#  'California',
#  'Maryland',
#  'Florida',
#  'California',
#  'Nevada',
#  'New Mexico',
#  'Colorado',
#  'Illinois',
#  'Connecticut',
#  'New York',
#  'Maryland',
#  'Mississippi',
#  'Kansas',
#  'Maryland',
#  'Nebraska',
#  'Maine',
#  'Florida',
#  'Wyoming',
#  'Illinois',
#  'West Virginia',
#  'Minnesota',
#  'Indiana',
#  'Nebraska',
#  'Ohio',
#  'Illinois',
#  'South Carolina',
#  'Tennessee',
#  'Iowa',
#  'South Dakota',
#  'Indiana',
#  'West Virginia',
#  'Idaho',
#  'Washington',
#  'Wyoming',
#  'Kentucky',
#  'New York',
#  'Alaska',
#  'West Virginia',
#  'Tennessee',
#  'Kansas',
#  'Rhode Island',
#  'Michigan',
#  'Nevada',
#  'Utah',
#  'Massachusetts',
#  'Nebraska',
#  'Michigan',
#  'Vermont',
#  'New Jersey',
#  'Mississippi',
#  'Montana',
#  'South Carolina',
#  'Georgia',
#  'New Hampshire',
#  'Kentucky',
#  'Pennsylvania',
#  'Vermont',
#  'New Hampshire',
#  'New Hampshire',
#  'Illinois',
#  'Rhode Island',
#  'Kansas',
#  'West Virginia',
#  'Kansas',
#  'North Carolina',
#  'Iowa',
#  'Arizona',
#  'Indiana',
#  'Wisconsin',
#  'North Dakota',
#  'Oregon',
#  'Wisconsin',
#  'Pennsylvania',
#  'Alabama',
#  'Minnesota',
#  'Pennsylvania',
#  'Kansas',
#  'New York',
#  'Illinois',
#  'California',
#  'Delaware',
#  'Oregon',
#  'Wyoming',
#  'Indiana',
#  'Pennsylvania',
#  'Illinois',
#  'Rhode Island',
#  'Georgia',
#  'Georgia',
#  'Minnesota',
#  'Kansas',
#  'Wyoming',
#  'North Carolina',
#  'Wisconsin',
#  'Colorado',
#  'Montana',
#  'Massachusetts',
#  'Massachusetts',
#  'North Carolina',
#  'South Carolina',
#  'California',
#  'Wyoming',
#  'Hawaii',
#  'New Mexico',
#  'South Carolina',
#  'Massachusetts',
#  'Pennsylvania',
#  'Georgia',
#  'New York',
#  'Nevada',
#  'Oregon',
#  'Arkansas',
#  'Arizona',
#  'Minnesota',
#  'Arkansas',
#  'Georgia',
#  'New Mexico',
#  'New Jersey',
#  'Missouri',
#  'Missouri',
#  'Kansas',
#  'Massachusetts',
#  'Mississippi',
#  'Connecticut',
#  'Maryland',
#  'South Carolina',
#  'Vermont',
#  'Arkansas',
#  'Washington',
#  'Alabama',
#  'New Jersey',
#  'Alaska',
#  'Arizona',
#  'Arizona',
#  'Iowa',
#  'Kentucky',
#  'North Carolina',
#  'Michigan',
#  'Oklahoma',
#  'Texas',
#  'Montana',
#  'Arkansas',
#  'North Carolina',
#  'Missouri',
#  'Florida',
#  'West Virginia',
#  'Missouri',
#  'Florida',
#  'Utah',
#  'Washington',
#  'North Dakota',
#  'Massachusetts',
#  'Maine',
#  'South Carolina',
#  'Massachusetts',
#  'Alaska',
#  'South Dakota',
#  'Illinois',
#  'Georgia',
#  'Washington',
#  'North Carolina',
#  'New Hampshire',
#  'Mississippi',
#  'Nevada',
#  'Mississippi',
#  'Montana',
#  'Washington',
#  'New Hampshire',
#  'Maine',
#  'Tennessee',
#  'Louisiana',
#  'Indiana',
#  'Washington',
#  'Texas',
#  'Colorado',
#  'South Carolina',
#  'Montana',
#  'Arkansas',
#  'Utah',
#  'Arizona',
#  'Virginia',
#  'Virginia',
#  'Mississippi',
#  'Mississippi',
#  'Mississippi',
#  'New Mexico',
#  'Delaware',
#  'South Dakota',
#  'Tennessee',
#  'Connecticut',
#  'Vermont',
#  'Connecticut',
#  'Rhode Island',
#  'Idaho',
#  'New York',
#  'Tennessee',
#  'Colorado',
#  'Pennsylvania',
#  'Alaska',
#  'Colorado',
#  'Louisiana',
#  'Wyoming',
#  'Arizona',
#  'Massachusetts',
#  'Hawaii',
#  'Colorado',
#  'Louisiana',
#  'Maine',
#  'Idaho',
#  'Oklahoma',
#  'Wisconsin',
#  'Massachusetts',
#  'Washington',
#  'California',
#  'California',
#  'Alabama',
#  'Delaware',
#  'Rhode Island',
#  'Kentucky',
#  'New Jersey',
#  'Massachusetts',
#  'North Carolina',
#  'Ohio',
#  'Indiana',
#  'Florida',
#  'Utah',
#  'Tennessee',
#  'Arizona',
#  'North Carolina',
#  'Colorado',
#  'Washington',
#  'Idaho',
#  'New Mexico',
#  'Michigan',
#  'Florida',
#  'Alabama',
#  'South Dakota',
#  'Georgia',
#  'North Dakota',
#  'Alabama',
#  'Vermont',
#  'Texas',
#  'New York',
#  'Massachusetts',
#  'New Mexico',
#  'Louisiana',
#  'Indiana',
#  'Ohio',
#  'Mississippi',
#  'South Carolina',
#  'Virginia',
#  'Georgia',
#  'Connecticut',
#  'North Dakota',
#  'Indiana',
#  'Arkansas',
#  'New Mexico',
#  'California',
#  'Texas',
#  'Indiana',
#  'Hawaii',
#  'Rhode Island',
#  'New Jersey',
#  'Mississippi',
#  'Tennessee',
#  'Tennessee',
#  'New York',
#  'North Carolina',
#  'South Carolina',
#  'Florida',
#  'New Jersey',
#  'Illinois',
#  'Delaware',
#  'Hawaii',
#  'Virginia',
#  'California',
#  'New Hampshire',
#  'Iowa',
#  'North Dakota',
#  'Maine',
#  'Colorado',
#  'Oklahoma',
#  'Kentucky',
#  'Vermont',
#  'Alabama',
#  'Hawaii',
#  'Tennessee',
#  'Mississippi',
#  'Nevada',
#  'Idaho',
#  'Hawaii',
#  'Connecticut',
#  'Hawaii',
#  'Florida',
#  'Oklahoma',
#  'South Carolina',
#  'Vermont',
#  'Arizona',
#  'Michigan',
#  'New Jersey',
#  'Oregon',
#  'Connecticut',
#  'Illinois',
#  'Nebraska',
#  'Wisconsin',
#  'Nebraska',
#  'Indiana',
#  'Pennsylvania',
#  'New Mexico',
#  'Florida',
#  'Indiana',
#  'Indiana',
#  'Virginia',
#  'Massachusetts',
#  'Vermont',
#  'Massachusetts',
#  'Missouri',
#  'California',
#  'Ohio',
#  'Nevada',
#  'North Dakota',
#  'Colorado',
#  'Connecticut',
#  'Oregon',
#  'New York',
#  'South Dakota',
#  'South Dakota',
#  'Pennsylvania',
#  'Pennsylvania',
#  'Pennsylvania',
#  'California',
#  'Delaware',
#  'Utah',
#  'South Carolina',
#  'Ohio',
#  'Kansas',
#  'West Virginia',
#  'Ohio',
#  'Oklahoma',
#  'Kansas',
#  'North Dakota',
#  'Georgia',
#  'Arizona',
#  'Maryland',
#  'Arizona',
#  'New Jersey',
#  'Alaska',
#  'Oklahoma',
#  'Nevada',
#  'Iowa',
#  'Alabama',
#  'Rhode Island',
#  'Arkansas',
#  'North Carolina',
#  'Missouri',
#  'Louisiana',
#  'South Dakota',
#  'North Dakota',
#  'South Carolina',
#  'Arkansas',
#  'Maryland',
#  'Rhode Island',
#  'Nevada',
#  'Iowa',
#  'Idaho',
#  'South Dakota',
#  'California',
#  'Massachusetts',
#  'Ohio',
#  'Minnesota',
#  'South Dakota',
#  'New Mexico',
#  'Illinois',
#  'Michigan',
#  'Missouri',
#  'Nebraska',
#  'Kentucky',
#  'North Carolina',
#  'Hawaii',
#  'Alabama',
#  'Florida',
#  'Washington',
#  'North Dakota',
#  'Virginia',
#  'Maine',
#  'Indiana',
#  'Pennsylvania',
#  'Louisiana',
#  'Delaware',
#  'Oregon',
#  'Minnesota',
#  'North Dakota',
#  'Wisconsin',
#  'Maryland',
#  'Georgia',
#  'Kentucky',
#  'Oklahoma',
#  'Oregon',
#  'Nebraska',
#  'Oregon',
#  'South Dakota',
#  'Nevada',
#  'Alabama',
#  'Nebraska',
#  'Connecticut',
#  'Minnesota',
#  'Wyoming',
#  'Massachusetts',
#  'Oregon',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'Missouri',
#  'Florida',
#  'New Mexico',
#  'Louisiana',
#  'Kansas',
#  'Colorado',
#  'Kentucky',
#  'Georgia',
#  'Iowa',
#  'New York',
#  'Minnesota',
#  'Kentucky',
#  'Oregon',
#  'Maryland',
#  'West Virginia',
#  'Kansas',
#  'Minnesota',
#  'South Carolina',
#  'Alabama',
#  'California',
#  'New York',
#  'Maine',
#  'Colorado',
#  'Louisiana',
#  'Delaware',
#  'Arkansas',
#  'Iowa',
#  'State',
#  'Wyoming',
#  'Nebraska',
#  'Louisiana',
#  'Wisconsin',
#  'Michigan',
#  'Vermont',
#  'Oregon',
#  'Kentucky',
#  'Washington',
#  'Pennsylvania',
#  'North Dakota',
#  'Minnesota',
#  'Texas',
#  'Maine',
#  'New Mexico',
#  'Oklahoma',
#  'California',
#  'Nevada',
#  'Arizona',
#  'Alaska',
#  'Tennessee',
#  'South Dakota',
#  'Maine',
#  'Oregon',
#  'Texas',
#  'South Carolina',
#  'Montana',
#  'South Dakota',
#  'Indiana',
#  'Washington',
#  'Oregon',
#  'South Carolina',
#  'Connecticut',
#  'South Dakota',
#  'Vermont',
#  'Louisiana',
#  'Minnesota',
#  'Kansas',
#  'Florida',
#  'North Dakota',
#  'Tennessee',
#  'New York',
#  'Missouri',
#  'Delaware',
#  'Maine',
#  'New Hampshire',
#  'California',
#  'Maine',
#  'Delaware',
#  'Arkansas',
#  'Idaho',
#  'Colorado',
#  'Alaska',
#  'Georgia',
#  'Tennessee',
#  'Idaho',
#  'New Hampshire',
#  'Oregon',
#  'Alaska',
#  'Georgia',
#  'Virginia',
#  'Georgia',
#  'West Virginia',
#  'Mississippi',
#  'Tennessee',
#  'Maryland',
#  'Nebraska',
#  'California',
#  'Iowa',
#  'Wyoming',
#  'Maine',
#  'Montana',
#  'New Hampshire',
#  'New York',
#  'Idaho',
#  'Idaho',
#  'Ohio',
#  'South Carolina',
#  'Mississippi',
#  'North Carolina',
#  'New Jersey',
#  'Nevada',
#  'New Mexico',
#  'West Virginia',
#  'Kansas',
#  'Maine',
#  'Iowa',
#  'Hawaii',
#  'North Dakota',
#  'Maryland',
#  'Ohio',
#  'Tennessee',
#  'Louisiana',
#  'Illinois',
#  'Arizona',
#  'New Hampshire',
#  'Wisconsin',
#  'Mississippi',
#  'Idaho',
#  'New York',
#  'New Jersey',
#  'West Virginia',
#  'Oregon',
#  'Michigan',
#  'Nevada',
#  'Wisconsin',
#  'Delaware',
#  'Massachusetts',
#  'Iowa',
#  'Rhode Island',
#  'Wyoming',
#  'Texas',
#  'North Dakota',
#  'Mississippi',
#  'Kansas',
#  'New Hampshire',
#  'Kansas',
#  'Alabama',
#  'Kentucky',
#  'New Jersey',
#  'Rhode Island',
#  'New Jersey',
#  'South Dakota',
#  'Rhode Island',
#  'Montana',
#  'Wisconsin',
#  'North Carolina',
#  'Maine',
#  'South Dakota',
#  'West Virginia',
#  'Florida',
#  'Idaho',
#  'North Carolina',
#  'New Jersey',
#  'Kansas',
#  'South Dakota',
#  'West Virginia',
#  'Wisconsin',
#  'Texas',
#  'Hawaii',
#  'Arizona',
#  'Louisiana',
#  'Hawaii',
#  'New York',
#  'Montana',
#  'Virginia',
#  'Texas',
#  'West Virginia',
#  'Minnesota',
#  'New York',
#  'Missouri',
#  'Arkansas',
#  'Kansas',
#  'Delaware',
#  'Colorado',
#  'Mississippi',
#  'Nevada',
#  'West Virginia',
#  'Missouri',
#  'Indiana',
#  'Tennessee',
#  'Illinois',
#  'Ohio',
#  'Virginia',
#  'Maine',
#  'Nevada',
#  'Maine',
#  'New York',
#  'Rhode Island',
#  'Montana',
#  'New Jersey',
#  'New Jersey',
#  'Oregon',
#  'Idaho',
#  'Hawaii',
#  'Oregon',
#  'Minnesota',
#  'Iowa',
#  'Georgia',
#  'Minnesota',
#  'Michigan',
#  'Georgia',
#  'South Carolina',
#  'Missouri',
#  'Colorado',
#  'South Dakota',
#  'South Carolina',
#  'Arkansas',
#  'North Carolina',
#  'Ohio',
#  'Louisiana',
#  'Vermont',
#  'North Carolina',
#  'Connecticut',
#  'Texas',
#  'North Carolina',
#  'Idaho',
#  'Arizona',
#  'Georgia',
#  'Iowa',
#  'New Jersey',
#  'North Carolina',
#  'Indiana',
#  'Kansas',
#  'Colorado',
#  'Tennessee',
#  'Tennessee',
#  'Maryland',
#  'Delaware',
#  'Texas',
#  'Alaska',
#  'Montana',
#  'Michigan',
#  'West Virginia',
#  'Connecticut',
#  'Michigan',
#  'Nevada',
#  'Nevada',
#  'Oklahoma',
#  'North Dakota',
#  'Wyoming',
#  'Oklahoma',
#  'New Jersey',
#  'Iowa',
#  'Rhode Island',
#  'Virginia',
#  'Connecticut',
#  'Michigan',
#  'Kentucky',
#  'Massachusetts',
#  'Idaho',
#  'South Carolina',
#  'Arizona',
#  'Kentucky',
#  'Oklahoma',
#  'Wyoming',
#  'Illinois',
#  'North Carolina',
#  'West Virginia',
#  'Louisiana',
#  'Indiana',
#  'Georgia',
#  'Wisconsin',
#  'Missouri',
#  'Virginia',
#  'Alabama',
#  'Iowa',
#  'Maine',
#  'Georgia',
#  'Alaska',
#  'Alabama',
#  'North Carolina',
#  'Nebraska',
#  'South Dakota',
#  'Michigan',
#  'Iowa',
#  'West Virginia',
#  'West Virginia',
#  'Illinois',
#  'Maine',
#  'Louisiana',
#  'Maine',
#  'Mississippi',
#  'Wisconsin',
#  'Idaho',
#  'Wisconsin',
#  'Texas',
#  'Louisiana',
#  'Alaska',
#  'Vermont',
#  'Ohio',
#  'New Hampshire',
#  'New Jersey',
#  'Oregon',
#  'Arizona',
#  'Oregon',
#  'Louisiana',
#  'Maine',
#  'Michigan',
#  'West Virginia',
#  'Arizona',
#  'Oregon',
#  'Virginia',
#  'Hawaii',
#  'California',
#  'Alabama',
#  'North Dakota',
#  'Kansas',
#  'Alabama',
#  'Minnesota',
#  'Kentucky',
#  'Pennsylvania',
#  'Wyoming',
#  'South Dakota',
#  'Oregon',
#  'Massachusetts',
#  'Michigan',
#  'Missouri',
#  'Michigan',
#  'Indiana',
#  'Nebraska',
#  'Wyoming',
#  'Vermont',
#  'Vermont',
#  'Nevada',
#  'New Mexico',
#  'Iowa',
#  'Indiana',
#  'West Virginia',
#  'West Virginia',
#  'Minnesota',
#  'Oregon',
#  'Delaware',
#  'Connecticut',
#  'Illinois',
#  'New Hampshire',
#  'Pennsylvania',
#  'Nebraska',
#  'Delaware',
#  'Illinois',
#  'New Jersey',
#  'North Carolina',
#  'Oklahoma',
#  'Oklahoma',
#  'North Dakota',
#  'New Hampshire',
#  'New Jersey',
#  'Tennessee',
#  'Alaska',
#  'Arizona',
#  'Indiana',
#  'Arkansas',
#  'New Jersey',
#  'New Hampshire',
#  'Indiana',
#  'Oregon',
#  'Missouri',
#  'Rhode Island',
#  'Iowa',
#  'Wyoming',
#  'Wisconsin',
#  'New York',
#  'Idaho',
#  'Utah',
#  'Alaska',
#  'Illinois',
#  'West Virginia',
#  'Hawaii',
#  ...]

# %%
st=[]
for i in range(1,numrows):
    currentstate=state[i]
    st.append(us_state_abbrev[currentstate])
    
    

# numstate=numrows-1
# currentstate=[]
# for i in range(0,10):
#     state[i]
# state
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-25585b67b51b> in <module>()
#       2 for i in range(1,numrows):
#       3     currentstate=state[i]
# ----> 4     st.append(us_state_abbrev[currentstate])
#       5
#       6
#
# KeyError: 'State'
